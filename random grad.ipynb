# %%
import torch
from torchzero.optim import RandomGrad, RandomBestGrad
from image_descent import ImageDescent, FunctionDescent2D, surfaces
# you can put path to an image or a numpy array / torch tensor.
# It will be converted into black-and-white channel-last.
image = r"F:\Stuff\Programming\AI\pytorch image descent\surfaces\spiral.jpg"

# coords are the initial coordinate to start optimization from
# either pixel location (int), or relative coordinates in (-1,-1) to (1,1) range (float).
descent = ImageDescent(image, coords=(915, 500))

torch.set_grad_enabled(False)
optimizer = RandomGrad(descent.parameters(), lr = 1e-5, mul=1000, opt = torch.optim.SGD(descent.parameters(), lr=2), step_opposite=True)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd)
descent.plot_path()
# Out:
# 999

# %%
import torch
from torchzero.optim import RandomGrad, RandomBestGrad
from image_descent import ImageDescent, FunctionDescent2D, surfaces
# you can put path to an image or a numpy array / torch tensor.
# It will be converted into black-and-white channel-last.
image = r"F:\Stuff\Programming\AI\pytorch image descent\surfaces\spiral.jpg"

# coords are the initial coordinate to start optimization from
# either pixel location (int), or relative coordinates in (-1,-1) to (1,1) range (float).
descent = ImageDescent(image, coords=(915, 500))

torch.set_grad_enabled(False)
optimizer = RandomGrad(descent.parameters(), lr = 1e-5, mul=1000, opt = torch.optim.SGD(descent.parameters(), lr=0.5, momentum=0.9), step_opposite=True)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd)
descent.plot_path()
# Out:
# 999

# %%
import torch
from torchzero.optim import RandomGrad, RandomBestGrad
from image_descent import ImageDescent, FunctionDescent2D, surfaces
# you can put path to an image or a numpy array / torch tensor.
# It will be converted into black-and-white channel-last.
image = r"F:\Stuff\Programming\AI\pytorch image descent\surfaces\spiral.jpg"

# coords are the initial coordinate to start optimization from
# either pixel location (int), or relative coordinates in (-1,-1) to (1,1) range (float).
descent = ImageDescent(image, coords=(915, 500))

torch.set_grad_enabled(False)
optimizer = RandomGrad(descent.parameters(), lr = 1e-5, mul=1000, opt = torch.optim.SGD(descent.parameters(), lr=0.5, momentum=0.9, nesterov=True), step_opposite=True)
for i in range(500):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd)
descent.plot_path()
# Out:
# 499

# %%
import torch
from torchzero.optim import RandomGrad, RandomBestGrad
from image_descent import ImageDescent, FunctionDescent2D, surfaces
# you can put path to an image or a numpy array / torch tensor.
# It will be converted into black-and-white channel-last.
image = r"F:\Stuff\Programming\AI\pytorch image descent\surfaces\spiral.jpg"

# coords are the initial coordinate to start optimization from
# either pixel location (int), or relative coordinates in (-1,-1) to (1,1) range (float).
descent = ImageDescent(image, coords=(915, 500))

torch.set_grad_enabled(False)
optimizer = RandomGrad(descent.parameters(), lr = 1e-4, mul=100, opt = torch.optim.AdamW(descent.parameters(), lr=5e-2), step_opposite=True)
for i in range(500):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd)
descent.plot_path()
# Out:
# 499

# %%
import torch
from stuff.found.torch.optim.Adan import Adan
from torchzero.optim import RandomGrad, RandomBestGrad
from image_descent import ImageDescent, FunctionDescent2D, surfaces
# you can put path to an image or a numpy array / torch tensor.
# It will be converted into black-and-white channel-last.
image = r"F:\Stuff\Programming\AI\pytorch image descent\surfaces\spiral.jpg"

# coords are the initial coordinate to start optimization from
# either pixel location (int), or relative coordinates in (-1,-1) to (1,1) range (float).
descent = ImageDescent(image, coords=(915, 500))

torch.set_grad_enabled(False)
optimizer = RandomGrad(descent.parameters(), lr = 1e-4, mul=100, opt = Adan(descent.parameters(), lr=1e-1), step_opposite=True)
for i in range(500):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd)
descent.plot_path()
# Out:
# 499
