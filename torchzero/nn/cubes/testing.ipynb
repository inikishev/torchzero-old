# %%
from glio.importsall import *
from torchzero.nn.nets.unet import SegResNet # type:ignore
from torchzero.nn.cubes import *

def get_model():
    return SegResNet(12, 5, 2, upsample=UpsampleCube.partial('bilinear'), decoder_channels_module='straight')

print(f"{count_parameters(get_model()) = }")
summary(get_model(), (1, 12, 96, 96))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [1], line 8
#       5 def get_model():
#       6     return SegResNet(12, 5, 2, upsample=UpsampleCube.partial('bilinear'), decoder_channels_module='straight')
# ----> 8 print(f"{count_parameters(get_model()) = }")
#       9 summary(get_model(), (1, 12, 96, 96))
#
# Cell In [1], line 6, in get_model()
#       5 def get_model():
# ----> 6     return SegResNet(12, 5, 2, upsample=UpsampleCube.partial('bilinear'), decoder_channels_module='straight')
#
# ...
