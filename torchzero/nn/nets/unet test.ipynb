# %%
import torch

from torchzero.nn.nets.unet import BasicUNet

# %%
model = BasicUNet(12, 5, 2)
model
# Out:
# BasicUNet(
#   (first): ChainCube(
#     (blocks): Sequential(
#       (0): ConvCube(
#         (layers): Sequential(
#           (0): Conv2d(12, 32, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): SpatialReduceCrop()
#           (2): ReLU(inplace=True)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): Dropout2d(p=0.5, inplace=False)
#         )
#       )
#       (1): ConvCube(
#         (layers): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): SpatialReduceCrop()
#           (2): ReLU(inplace=True)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): Dropout2d(p=0.5, inplace=False)
#         )
#       )
#     )
#   )
#   (down): ModuleList(
#     (0): StraightAndResizeCube(
#       (blocks): Sequential(
#         (0): ConvCube(
# ...

# %%
model(torch.randn(4, 12, 96, 96)).shape
# Out:
# torch.Size([4, 5, 96, 96])
