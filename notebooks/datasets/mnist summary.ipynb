# %%
from glio.logger.compare import Comparison

comp = Comparison.from_checkpoint_folder(r"checkpoints")
print(comp.keys())
# Out:
# ['test accuracy', 'param var', 'param path mean', 'param min', 'param mean', 'update angle', 'update var', 'time', 'last updates std', 'update path mean', 'train accuracy', 'lr', 'train loss', 'test loss', 'param max']

# %%
comp.plot_best('test loss', criterion='min', figsize=(12, 8), linewidth=1)

# %%
comp.plot_best('test accuracy', criterion='max',figsize=(12, 8), linewidth=1,)
