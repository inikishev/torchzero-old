# %%
import torch
from torchzero.optim.zeroth_order.random_search import AcceleratedRandomSearch
from image_descent import ImageDescent, FunctionDescent2D, surfaces

image = r"F:\Stuff\Programming\AI\pytorch image descent\surfaces\spiral.jpg"

# %%
descent = ImageDescent(image, coords=(915, 500))

optimizer = AcceleratedRandomSearch(descent.parameters(), [-1, 1], shrink = 0.9, restart_steps=100)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
    descent.step_nograd()
descent.plot_path()
# Out:
# 999
