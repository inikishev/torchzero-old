# %%
import torch
from torchzero.optim import FDSA
from image_descent import ImageDescent, FunctionDescent2D, surfaces

image = r"F:\Stuff\Programming\AI\pytorch image descent\surfaces\spiral.jpg"

# %%
descent = ImageDescent(image, coords=(915, 500))

optimizer = FDSA(descent.parameters(), lr=1e-1, magn=1e-3)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
    descent.step_nograd()
descent.plot_path()
# Out:
# 999

# %% [markdown]
# # Comparison to SGD

# %%
descent = ImageDescent(image, coords=(915, 500))

optimizer = torch.optim.SGD(descent.parameters(), lr=4e-1)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step)
descent.plot_path()
# Out:
# 999
