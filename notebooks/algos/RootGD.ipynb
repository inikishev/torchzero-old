# %%
import torch
from torchzero.optim.first_order import RootGD
from torchzero.optim.first_order.gd import GD
from image_descent import ImageDescent, FunctionDescent2D, surfaces
from glio.plot import *

image = r"F:\Stuff\Programming\AI\pytorch image descent\surfaces\spiral.jpg"

# %%
descent = ImageDescent(image, coords=(915, 500))

optimizer = RootGD(descent.parameters(), 5e-2)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    descent.step()
    optimizer.step()
descent.plot_path()
# Out:
# 999

# %%
descent = FunctionDescent2D(surfaces.sphere)
optimizer = RootGD(descent.parameters(), lr = 1)
for i in range(100):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()

# %%
descent = FunctionDescent2D(surfaces.rosenbrock)
optimizer = RootGD(descent.parameters(), lr = 5e-1)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()

# %%
descent = FunctionDescent2D(surfaces.rastrigin)
optimizer = RootGD(descent.parameters(), lr = 5e-1)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()

# %%
descent = FunctionDescent2D(surfaces.ackley)
optimizer = RootGD(descent.parameters(), lr = 3)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()

# %%
descent = FunctionDescent2D(surfaces.beale)
optimizer = RootGD(descent.parameters(), lr = 1)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()

# %%
descent = FunctionDescent2D(surfaces.booth)
optimizer = RootGD(descent.parameters(), lr = 1, root=2)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print(i, loss, end = '\r')

descent.plot_path()
# Out:
# 999 tensor(2.0882e-08, grad_fn=<DivBackward0>)tensor(2.0882e-08, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(surfaces.booth)
optimizer = RootGD(descent.parameters(), lr = 1, root=10)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print(i, loss, end = '\r')

descent.plot_path()
# Out:
# 999 tensor(3.3600e-05, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(surfaces.PowSum(5,3))
optimizer = RootGD(descent.parameters(), lr = 5e-2)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()

# %%
descent = FunctionDescent2D(surfaces.cross)
optimizer = RootGD(descent.parameters(), lr = 1e-2)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()
