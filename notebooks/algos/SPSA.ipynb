# %%
import torch
from torchzero.optim import SPSA
from image_descent import ImageDescent, FunctionDescent2D, surfaces

image = r"F:\Stuff\Programming\AI\pytorch image descent\surfaces\spiral.jpg"

# %%
descent = ImageDescent(image, coords=(915, 500))

optimizer = SPSA(descent.parameters(), lr=5e-2, magn=3e-3, max_diff=1e-2)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
    descent.step_nograd()
descent.plot_path()
# Out:
# 999

# %%
descent = ImageDescent(image, coords=(915, 500))

optimizer = SPSA(descent.parameters(), variant = 'RDSA', sampler=torch.randn, lr=2e-2, magn=3e-3, max_diff=1e-2)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
    descent.step_nograd()
descent.plot_path()
# Out:
# 999

# %%
descent = ImageDescent(image, coords=(915, 500))

optimizer = SPSA(descent.parameters(), variant = '2step', lr=8e-2, magn=3e-3, max_diff=1e-2)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
    descent.step_nograd()
descent.plot_path()
# Out:
# 999

# %%
descent = ImageDescent(image, coords=(915, 500))

optimizer = SPSA(descent.parameters(), variant = '2step', sampler = torch.randn, lr=5e-2, magn=3e-3, max_diff=1e-2)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
    descent.step_nograd()
descent.plot_path()
# Out:
# 999
