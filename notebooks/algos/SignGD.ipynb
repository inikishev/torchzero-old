# %%
import torch
from torchzero.optim.first_order import SignGD
from torchzero.optim.first_order.gd import GD
from image_descent import ImageDescent, FunctionDescent2D, surfaces
from glio.plot import *

image = r"F:\Stuff\Programming\AI\pytorch image descent\surfaces\spiral.jpg"

# %%
descent = ImageDescent(image, coords=(915, 500))

optimizer = SignGD(descent.parameters(), 3e-2)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    descent.step()
    optimizer.step()
descent.plot_path()
# Out:
# 999

# %%
descent = FunctionDescent2D(surfaces.sphere)
optimizer = SignGD(descent.parameters(), lr = 0.2)
for i in range(100):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()

# %%
descent = FunctionDescent2D(surfaces.rosenbrock)
optimizer = SignGD(descent.parameters(), lr = 0.05)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()

# %%
descent = FunctionDescent2D(surfaces.rastrigin)
optimizer = SignGD(descent.parameters(), lr = 5e-1)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()

# %%
descent = FunctionDescent2D(surfaces.ackley)
optimizer = SignGD(descent.parameters(), lr = 1)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()

# %%
descent = FunctionDescent2D(surfaces.beale)
optimizer = SignGD(descent.parameters(), lr = 2e-1)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()

# %%
descent = FunctionDescent2D(surfaces.booth)
optimizer = SignGD(descent.parameters(), lr = 1)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()

# %%
descent = FunctionDescent2D(surfaces.PowSum(5,3))
optimizer = SignGD(descent.parameters(), lr = 1e-1)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()

# %%
descent = FunctionDescent2D(surfaces.cross)
optimizer = SignGD(descent.parameters(), lr = 1e-1)
for i in range(1000):
    loss = descent.step()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

descent.plot_path()
