# %%
import optuna, optuna_integration, optunahub
import torch
from torchzero.optim.integrations.optuna import OptunaOptimizer
from image_descent import ImageDescent, FunctionDescent2D, surfaces

image = r"F:\Stuff\Programming\AI\pytorch image descent\surfaces\spiral.jpg"

# %%
descent = ImageDescent(image, coords=(915, 500))

sampler = optuna.samplers.RandomSampler()
optimizer = OptunaOptimizer(descent.parameters(), sampler = sampler, domain = (-1, 1))
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
descent.plot_path()
# Out:
# 999

# %%
descent = ImageDescent(image, coords=(915, 500))

sampler = optuna.samplers.TPESampler()
optimizer = OptunaOptimizer(descent.parameters(), sampler = sampler, domain = (-1, 1))
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
descent.plot_path()
# Out:
# 999

# %%
descent = ImageDescent(image, coords=(915, 500))

sampler = optuna.samplers.CmaEsSampler()
optimizer = OptunaOptimizer(descent.parameters(), sampler = sampler, domain = (-1, 1))
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
descent.plot_path()
# Out:
# 999

# %%
descent = ImageDescent(image, coords=(915, 500))

sampler = optuna.samplers.NSGAIISampler()
optimizer = OptunaOptimizer(descent.parameters(), sampler = sampler, domain = (-1, 1))
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
descent.plot_path()
# Out:
# 999

# %%
descent = ImageDescent(image, coords=(915, 500))

sampler = optuna.samplers.QMCSampler()
optimizer = OptunaOptimizer(descent.parameters(), sampler = sampler, domain = (-1, 1))
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
descent.plot_path()
# Out:
# C:\Users\nkshv\AppData\Local\Temp\ipykernel_2352\630622139.py:3: ExperimentalWarning: QMCSampler is experimental (supported from v3.0.0). The interface can change in the future.
#   sampler = optuna.samplers.QMCSampler()
# 999

# %%
descent = ImageDescent(image, coords=(915, 500))

sampler = optuna.samplers.GPSampler(deterministic_objective=True)
optimizer = OptunaOptimizer(descent.parameters(), sampler = sampler, domain = (-1, 1), enable_grad=True)
for i in range(100):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
descent.plot_path()
# Out:
# C:\Users\nkshv\AppData\Local\Temp\ipykernel_29152\4153528268.py:3: ExperimentalWarning: GPSampler is experimental (supported from v3.6.0). The interface can change in the future.
#   sampler = optuna.samplers.GPSampler(deterministic_objective=True)
# 99

# %%
descent = ImageDescent(image, coords=(915, 500))

sampler = optuna_integration.BoTorchSampler()
optimizer = OptunaOptimizer(descent.parameters(), sampler = sampler, domain = (-1, 1), enable_grad=True)
for i in range(100):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
descent.plot_path()
# Out:
# C:\Users\nkshv\AppData\Local\Temp\ipykernel_36468\2071722614.py:3: ExperimentalWarning: BoTorchSampler is experimental (supported from v2.4.0). The interface can change in the future.
#   sampler = optuna_integration.BoTorchSampler()
# d:\miniconda\envs\pytorch312\Lib\site-packages\optuna_integration\botorch.py:931: ExperimentalWarning: logei_candidates_func is experimental (supported from v3.3.0). The interface can change in the future.
#   candidates = self._candidates_func(
# 11
# d:\miniconda\envs\pytorch312\Lib\site-packages\optuna_integration\botorch.py:931: ExperimentalWarning: logei_candidates_func is experimental (supported from v3.3.0). The interface can change in the future.
#   candidates = self._candidates_func(
# 12
# d:\miniconda\envs\pytorch312\Lib\site-packages\optuna_integration\botorch.py:931: ExperimentalWarning: logei_candidates_func is experimental (supported from v3.3.0). The interface can change in the future.
#   candidates = self._candidates_func(
# 13
# ...

# %%
descent = ImageDescent(image, coords=(915, 500))

sampler = optuna_integration.PyCmaSampler()
optimizer = OptunaOptimizer(descent.parameters(), sampler = sampler, domain = (-1, 1), enable_grad=True)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
descent.plot_path()
# Out:
# 999

# %%
descent = ImageDescent(image, coords=(915, 500))

mod = optunahub.load_module("samplers/simulated_annealing")
sampler = mod.SimulatedAnnealingSampler()
optimizer = OptunaOptimizer(descent.parameters(), sampler = sampler, domain = (-1, 1), enable_grad=True)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
descent.plot_path()
# Out:
# 999

# %%
descent = ImageDescent(image, coords=(915, 500))

mod = optunahub.load_module("samplers/bbo_rietveld")
sampler = mod.BboRietveldSampler()
optimizer = OptunaOptimizer(descent.parameters(), sampler = sampler, domain = (-1, 1), enable_grad=True)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
descent.plot_path()
# Out:
# d:\miniconda\envs\pytorch312\Lib\site-packages\optuna\samplers\_tpe\sampler.py:319: ExperimentalWarning: ``multivariate`` option is an experimental feature. The interface can change in the future.
#   warnings.warn(
# d:\miniconda\envs\pytorch312\Lib\site-packages\optuna\samplers\_tpe\sampler.py:330: ExperimentalWarning: ``group`` option is an experimental feature. The interface can change in the future.
#   warnings.warn(
# 999

# %%
descent = ImageDescent(image, coords=(915, 500))

mod = optunahub.load_module("samplers/whale_optimization")
sampler = mod.WhaleOptimizationSampler()
optimizer = OptunaOptimizer(descent.parameters(), sampler = sampler, domain = (-1, 1), enable_grad=True)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
descent.plot_path()
# Out:
# 999

# %%
descent = ImageDescent(image, coords=(915, 500))

mod = optunahub.load_module("samplers/implicit_natural_gradient")
sampler = mod.ImplicitNaturalGradientSampler()
optimizer = OptunaOptimizer(descent.parameters(), sampler = sampler, domain = (-1, 1), enable_grad=True)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
descent.plot_path()
# Out:
# 999

# %%
descent = ImageDescent(image, coords=(915, 500))

mod = optunahub.load_module("samplers/uniform_design")
sampler = mod.UniformDesignSampler()
optimizer = OptunaOptimizer(descent.parameters(), sampler = sampler, domain = (-1, 1), enable_grad=True)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
descent.plot_path()
# Out:
# Request GET /repos/optuna/optunahub-registry/contents/package/samplers/uniform_design/uniform_design.py?ref=main failed with 403: rate limit exceeded
# Setting next backoff to 1144.939346s

# %%
descent = ImageDescent(image, coords=(915, 500))

mod = optunahub.load_module("samplers/catcma")
sampler = mod.CatCmaSampler()
optimizer = OptunaOptimizer(descent.parameters(), sampler = sampler, domain = (-1, 1), enable_grad=True)
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
descent.plot_path()
