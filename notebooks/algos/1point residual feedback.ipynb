# %%
import torch
from torchzero.optim.oprf import OnePointResidualFeeback
from image_descent import ImageDescent, FunctionDescent2D, surfaces

image = r"F:\Stuff\Programming\AI\pytorch image descent\surfaces\spiral.jpg"

# %%
descent = ImageDescent(image, coords=(915, 500))

optimizer = OnePointResidualFeeback(descent.parameters(), lr=2, magn=1e-3)
for i in range(10000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
    descent.step_nograd()
descent.plot_path()
# Out:
# 9999

# %%
descent = ImageDescent(image, coords=(915, 500))

optimizer = OnePointResidualFeeback(descent.parameters(), magn=1e-3, grad=True, opt=torch.optim.AdamW(descent.parameters(), 1e-2))
for i in range(1000):
    print(i, end='\r')
    optimizer.zero_grad()
    optimizer.step(descent.step_nograd_search)
    descent.step_nograd()
descent.plot_path()
# Out:
# 999
